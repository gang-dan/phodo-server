# %%
from google.colab import drive 
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
# %cd /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# !pwd
# Out:
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5

# %%
import os

# !git clone https://github.com/ultralytics/yolov5.git # clone

# %%
# %cd /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# %pip install -r requirements.txt # install

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2023-3-29 Python-3.9.16 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/weights/yolov5{x}.pt')

# %%
# %cd /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# !python segment/predict.py --weights weights/yolov5s-seg.pt --source data/images/custom_test/colo.jpg --name test-inference
# Out:
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# segment/predict: weights=['weights/yolov5s-seg.pt'], source=data/images/custom_test/colo.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=test-inference, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 2023-3-29 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients, 26.4 GFLOPs
# masks = torch.Size([15, 640, 480])
# im0 = (1440, 1080, 3)
# img shape -> height:1440, width:1080
# masks shape -> height:15, width:640
# mask 추출 시작합니다!!!!!!!!!
#
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# mask shape : (1440, 1080, 1)
# Traceback (most recent call last):
#   File "/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/segment/predict.py", line 371, in <module>
#   File "/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/segment/predict.py", line 366, in main
#     opt = parse_opt()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/segment/predict.py", line 257, in run
#     colors=[colors(x, True) for x in det[:, 5]],
#   File "/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/utils/plots.py", line 197, in masks
#
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py", line 1024, in savefig
#     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/backend_bases.py", line 2082, in draw_idle
#     self.draw(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/backends/backend_agg.py", line 400, in draw
#     self.figure.draw(self.renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/artist.py", line 95, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/figure.py", line 3140, in draw
#     mimage._draw_list_compositing_images(
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py", line 3064, in draw
#     mimage._draw_list_compositing_images(
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 641, in draw
#     im, l, b, trans = self.make_image(
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 949, in make_image
#     return self._make_image(self._A, bbox, transformed_bbox, clip,
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 553, in _make_image
#     output_alpha = _resample(  # resample alpha channel
#   File "/usr/local/lib/python3.9/dist-packages/matplotlib/image.py", line 207, in _resample
#     _image.resample(data, out, transform,
# KeyboardInterrupt
# ^C

# %%
display.Image(filename=f"/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5/runs/predict-seg/test-inference5/firenze.jpg", width=600)
