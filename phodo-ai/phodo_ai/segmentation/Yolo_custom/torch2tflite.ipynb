# %%
from google.colab import drive 
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom
# !pwd
# Out:
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %cd /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# !pwd
# Out:
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5
# /gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/yolov5

# %%
# !python export.py --weights yolov5s-seg.pt --include='tflite' --nms
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s-seg.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=True, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 2023-4-8 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients
#
# PyTorch: starting from yolov5s-seg.pt with output shape (1, 25200, 117) (14.9 MB)
# 2023-04-09 11:32:14.661402: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python export.py --weights yolov5s-seg.pt --include='saved_model' --nms
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s-seg.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=True, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['saved_model']
# YOLOv5 🚀 2023-4-8 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients
#
# PyTorch: starting from yolov5s-seg.pt with output shape (1, 25200, 117) (14.9 MB)
# 2023-04-08 17:26:45.146054: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python export.py --weights yolov5s-seg.pt --include='tflite' --int8
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s-seg.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=True, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 2023-3-29 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients
#
# PyTorch: starting from yolov5s-seg.pt with output shape (1, 25200, 117) (14.9 MB)
# 2023-04-08 14:37:55.173283: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python export.py --weights yolov5s-seg.pt --img 640 --batch 1 --include='tflite'
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s-seg.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 2023-3-29 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients
#
# PyTorch: starting from yolov5s-seg.pt with output shape (1, 25200, 117) (14.9 MB)
# 2023-04-07 10:26:09.989820: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import onnx
from onnx_tf.backend import prepare

onnx_model = onnx.load("./yolov5s-seg.onnx")
output = prepare(onnx_model).run(input)

# %%
# 미리 학습된 가중치를 읽어옵니다
model_url = './weights/yolov5s-seg.pt'
batch_size = 1    # 임의의 수

# 모델을 미리 학습된 가중치로 초기화합니다
map_location = lambda storage, loc: storage
if torch.cuda.is_available():
    map_location = None
torch_model.load_state_dict(model_zoo.load_url(model_url, map_location=map_location))

# 모델을 추론 모드로 전환합니다
torch_model.eval()
